# %%
import tensorflow as tf


celsius    = tf.constant([-40, -10,  0,  8, 15, 22,  38],  dtype=float)
fahrenheit = tf.constant([-40,  14, 32, 46, 59, 72, 100],  dtype=float)

celsius
# Out:
# <tf.Tensor: shape=(7,), dtype=float32, numpy=array([-40., -10.,   0.,   8.,  15.,  22.,  38.], dtype=float32)>

# %%
model = tf.keras.Sequential([
            tf.keras.layers.Dense(units=4, input_shape=[1]),
            tf.keras.layers.Dense(units=4),
            tf.keras.layers.Dense(units=1)
])
model.compile(loss='mean_squared_error',
              optimizer=tf.keras.optimizers.Adam(0.1))

# %%
model.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print("Finished training the model")
# Out:
# Finished training the model

# %%
print(model.predict([100])) # Truth = 212
# Out:
# [[211.74739]]
